# %%
import pandas as pd

# %%
df = pd.read_csv('data/fatal-police-shootings-data.csv')
df
# Out:
#         id                name        date   manner_of_death         armed  \
# 0        3          Tim Elliot  2015-01-02              shot           gun
# 1        4    Lewis Lee Lembke  2015-01-02              shot           gun
# 2        5  John Paul Quintero  2015-01-03  shot and Tasered       unarmed
# 3        8     Matthew Hoffman  2015-01-04              shot    toy weapon
# 4        9   Michael Rodriguez  2015-01-04              shot      nail gun
# ...    ...                 ...         ...               ...           ...
# 6082  6651                 NaN  2021-02-26  shot and Tasered           gun
# 6083  6644                 NaN  2021-02-27              shot  undetermined
# 6084  6645                 NaN  2021-02-27              shot           gun
# 6085  6646                 NaN  2021-02-27              shot  undetermined
# 6086  6647                 NaN  2021-02-27              shot           gun
#
# ...

# %%
grouped = df.groupby('state')
grouped.count().sort_values('id', ascending = False)
# Out:
#         id  name  date  manner_of_death  armed  age  gender  race  city  \
# state
# CA     900   834   900              900    872  837     900   796   900
# TX     539   491   539              539    522  498     539   477   539
# FL     405   384   405              405    391  383     405   374   405
# AZ     287   274   287              287    274  274     287   243   287
# CO     216   206   216              216    210  200     216   192   216
# GA     206   206   206              206    201  201     205   184   206
# OK     180   179   180              180    174  172     180   166   180
# WA     175   169   175              175    170  169     175   141   175
# NC     175   174   175              175    172  169     175   165   175
# OH     173   172   173              173    165  170     173   163   173
# TN     158   157   158              158    153  154     158   141   158
# MO     152   148   152              152    148  147     152   134   152
# ...

# %%
cali = df.loc[df['state'] == 'CA', :]
cali
# Out:
#         id                name        date   manner_of_death         armed  \
# 3        8     Matthew Hoffman  2015-01-04              shot    toy weapon
# 10      19      Patrick Wetter  2015-01-06  shot and Tasered         knife
# 22      43      Brian  Barbosa  2015-01-11              shot           gun
# 35      63           Jose Ceja  2015-01-15              shot         knife
# 38      68       Zaki Shinwary  2015-01-16  shot and Tasered         knife
# ...    ...                 ...         ...               ...           ...
# 6027  6568        Anthony Loia  2021-02-06              shot           gun
# 6032  6566  Brooke Leann Blair  2021-02-07              shot    toy weapon
# 6053  6614                 NaN  2021-02-15              shot  undetermined
# 6054  6615     Royce Robertson  2021-02-15              shot           gun
# 6074  6632                 NaN  2021-02-25              shot  undetermined
#
# ...

# %%
income = pd.read_csv('data/MedianHouseholdIncome2015.csv', encoding = 'unicode_escape')
income
# Out:
#       Geographic Area                    City Median Income
# 0                  AL              Abanda CDP         11207
# 1                  AL          Abbeville city         25615
# 2                  AL         Adamsville city         42575
# 3                  AL            Addison town         37083
# 4                  AL              Akron town         21667
# ...               ...                     ...           ...
# 29317              WY  Woods Landing-Jelm CDP           NaN
# 29318              WY            Worland city         41523
# 29319              WY             Wright town         77114
# 29320              WY              Yoder town         37500
# 29321              WY           Y-O Ranch CDP           NaN
#
# [29322 rows x 3 columns]

# %%
cali_income = income.loc[income['Geographic Area'] == 'CA', :]
cali_income
# Out:
#      Geographic Area                City Median Income
# 1932              CA  Acalanes Ridge CDP        156953
# 1933              CA          Acampo CDP        152713
# 1934              CA           Acton CDP         89150
# 1935              CA       Adelanto city         33298
# 1936              CA            Adin CDP           (X)
# ...              ...                 ...           ...
# 3449              CA          Yreka city         28333
# 3450              CA      Yuba City city         50649
# 3451              CA        Yucaipa city         56452
# 3452              CA   Yucca Valley town         40030
# 3453              CA         Zayante CDP         81513
#
# [1522 rows x 3 columns]

# %%
poverty = pd.read_csv('data/PercentagePeopleBelowPovertyLevel.csv', encoding = 'unicode_escape')

# %%
cali_pov = poverty.loc[poverty['Geographic Area'] == 'CA', :]
cali_pov
# Out:
#      Geographic Area                City poverty_rate
# 1932              CA  Acalanes Ridge CDP          2.5
# 1933              CA          Acampo CDP            0
# 1934              CA           Acton CDP          7.6
# 1935              CA       Adelanto city         40.3
# 1936              CA            Adin CDP         12.6
# ...              ...                 ...          ...
# 3449              CA          Yreka city         34.3
# 3450              CA      Yuba City city         18.5
# 3451              CA        Yucaipa city         16.7
# 3452              CA   Yucca Valley town           21
# 3453              CA         Zayante CDP          7.7
#
# [1522 rows x 3 columns]

# %%
education = pd.read_csv('data/PercentOver25CompletedHighSchool.csv', encoding = 'unicode_escape')

# %%
cali_edu = education.loc[education['Geographic Area'] == 'CA', :]
cali_edu
# Out:
#      Geographic Area                City percent_completed_hs
# 1932              CA  Acalanes Ridge CDP                  100
# 1933              CA          Acampo CDP                 77.1
# 1934              CA           Acton CDP                 88.2
# 1935              CA       Adelanto city                 67.5
# 1936              CA            Adin CDP                  100
# ...              ...                 ...                  ...
# 3449              CA          Yreka city                 84.4
# 3450              CA      Yuba City city                 78.3
# 3451              CA        Yucaipa city                 86.4
# 3452              CA   Yucca Valley town                 85.5
# 3453              CA         Zayante CDP                 96.4
#
# [1522 rows x 3 columns]

# %%
race = pd.read_csv('data/ShareRaceByCity.csv', encoding = 'unicode_escape')

# %%
cali_race = race.loc[race['Geographic area'] == 'CA', :]
cali_race
# Out:
#      Geographic area                City share_white share_black  \
# 1925              CA  Acalanes Ridge CDP        83.6         0.4
# 1926              CA          Acampo CDP        49.6           0
# 1927              CA           Acton CDP        86.4         0.8
# 1928              CA       Adelanto city        43.8        20.5
# 1929              CA            Adin CDP        88.2         0.7
# ...              ...                 ...         ...         ...
# 3443              CA          Yreka city        83.6         0.7
# 3444              CA      Yuba City city        57.6         2.5
# 3445              CA        Yucaipa city        79.5         1.6
# 3446              CA   Yucca Valley town        83.5         3.2
# 3447              CA         Zayante CDP        91.8         1.4
#
#      share_native_american share_asian share_hispanic
# 1925                   0.7        11.1            4.4
# 1926                   0.3         0.9           58.4
# ...
