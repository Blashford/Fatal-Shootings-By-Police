# %%
import pandas as pd

# %%
demo_info = pd.read_csv('data/full_census_data.csv')

# %%
demo_info.drop(columns = "Unnamed: 0")
# Out:
#       Geographic Area                    City Median Income  \
# 0                  AL              Abanda CDP         11207
# 1                  AL          Abbeville city         25615
# 2                  AL         Adamsville city         42575
# 3                  AL            Addison town         37083
# 4                  AL              Akron town         21667
# ...               ...                     ...           ...
# 29110              WY  Woods Landing-Jelm CDP           NaN
# 29111              WY            Worland city         41523
# 29112              WY             Wright town         77114
# 29113              WY              Yoder town         37500
# 29114              WY           Y-O Ranch CDP           NaN
#
#       percent_completed_hs poverty_rate share_white share_black  \
# 0                     21.2         78.8        67.2        30.2
# 1                     69.1         29.1        54.4        41.4
# ...

# %%
demo_info["City"] = demo_info['City'].str.rsplit(' ', n=1).str.get(0)

# %%
demo_info.head(20)
# Out:
#     Unnamed: 0 Geographic Area            City Median Income  \
# 0            0              AL          Abanda         11207
# 1            1              AL       Abbeville         25615
# 2            2              AL      Adamsville         42575
# 3            3              AL         Addison         37083
# 4            4              AL           Akron         21667
# 5            5              AL       Alabaster         71816
# 6            6              AL     Albertville         32911
# 7            7              AL  Alexander City         29874
# 8            8              AL      Alexandria         56058
# 9            9              AL      Aliceville         21131
# 10          10              AL         Allgood         42009
# 11          11              AL         Altoona         27566
# 12          12              AL       Andalusia         31968
# 13          13              AL        Anderson         34792
# ...

# %%
demo_info.to_csv('data/full_census_data.csv')
