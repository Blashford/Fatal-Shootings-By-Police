# %%
import pandas as pd

# %%
shooting_df = pd.read_csv('data/fatal-police-shootings-data.csv')
shooting_df
# Out:
#         id                name        date   manner_of_death         armed  \
# 0        3          Tim Elliot  2015-01-02              shot           gun
# 1        4    Lewis Lee Lembke  2015-01-02              shot           gun
# 2        5  John Paul Quintero  2015-01-03  shot and Tasered       unarmed
# 3        8     Matthew Hoffman  2015-01-04              shot    toy weapon
# 4        9   Michael Rodriguez  2015-01-04              shot      nail gun
# ...    ...                 ...         ...               ...           ...
# 6082  6651                 NaN  2021-02-26  shot and Tasered           gun
# 6083  6644                 NaN  2021-02-27              shot  undetermined
# 6084  6645                 NaN  2021-02-27              shot           gun
# 6085  6646                 NaN  2021-02-27              shot  undetermined
# 6086  6647                 NaN  2021-02-27              shot           gun
#
# ...

# %%
cali_shot = shooting_df.loc[shooting_df['state'] == 'CA', :]
cali_shot
# Out:
#         id                name        date   manner_of_death         armed  \
# 3        8     Matthew Hoffman  2015-01-04              shot    toy weapon
# 10      19      Patrick Wetter  2015-01-06  shot and Tasered         knife
# 22      43      Brian  Barbosa  2015-01-11              shot           gun
# 35      63           Jose Ceja  2015-01-15              shot         knife
# 38      68       Zaki Shinwary  2015-01-16  shot and Tasered         knife
# ...    ...                 ...         ...               ...           ...
# 6027  6568        Anthony Loia  2021-02-06              shot           gun
# 6032  6566  Brooke Leann Blair  2021-02-07              shot    toy weapon
# 6053  6614                 NaN  2021-02-15              shot  undetermined
# 6054  6615     Royce Robertson  2021-02-15              shot           gun
# 6074  6632                 NaN  2021-02-25              shot  undetermined
#
# ...

# %%
census_df = pd.read_csv('data/full_census_data.csv')
census_df = census_df.drop(columns=['Unnamed: 0', 'Unnamed: 0.1'])
census_df
# Out:
#       Geographic Area                City Median Income percent_completed_hs  \
# 0                  AL              Abanda         11207                 21.2
# 1                  AL           Abbeville         25615                 69.1
# 2                  AL          Adamsville         42575                 78.9
# 3                  AL             Addison         37083                 81.4
# 4                  AL               Akron         21667                 68.6
# ...               ...                 ...           ...                  ...
# 29110              WY  Woods Landing-Jelm           NaN                  100
# 29111              WY             Worland         41523                 85.6
# 29112              WY              Wright         77114                 89.2
# 29113              WY               Yoder         37500                 79.4
# 29114              WY           Y-O Ranch           NaN                  100
#
# ...

# %%
cali_census = census_df.loc[census_df['Geographic Area'] == 'CA', :]
cali_census
# Out:
#      Geographic Area            City Median Income percent_completed_hs  \
# 1917              CA  Acalanes Ridge        156953                  100
# 1918              CA          Acampo        152713                 77.1
# 1919              CA           Acton         89150                 88.2
# 1920              CA        Adelanto         33298                 67.5
# 1921              CA            Adin           (X)                  100
# ...              ...             ...           ...                  ...
# 3421              CA           Yreka         28333                 84.4
# 3422              CA       Yuba City         50649                 78.3
# 3423              CA         Yucaipa         56452                 86.4
# 3424              CA    Yucca Valley         40030                 85.5
# 3425              CA         Zayante         81513                 96.4
#
#      poverty_rate share_white share_black share_native_american share_asian  \
# ...

# %%
cali_census = cali_census.rename(columns = {'City': 'city'})
cali_census
# Out:
#      Geographic Area            city Median Income percent_completed_hs  \
# 1917              CA  Acalanes Ridge        156953                  100
# 1918              CA          Acampo        152713                 77.1
# 1919              CA           Acton         89150                 88.2
# 1920              CA        Adelanto         33298                 67.5
# 1921              CA            Adin           (X)                  100
# ...              ...             ...           ...                  ...
# 3421              CA           Yreka         28333                 84.4
# 3422              CA       Yuba City         50649                 78.3
# 3423              CA         Yucaipa         56452                 86.4
# 3424              CA    Yucca Valley         40030                 85.5
# 3425              CA         Zayante         81513                 96.4
#
#      poverty_rate share_white share_black share_native_american share_asian  \
# ...

# %%
cali_merged = cali_shot.merge(cali_census, how = 'left', on='city')
cali_merged
# Out:
#        id                name        date   manner_of_death         armed  \
# 0       8     Matthew Hoffman  2015-01-04              shot    toy weapon
# 1      19      Patrick Wetter  2015-01-06  shot and Tasered         knife
# 2      43      Brian  Barbosa  2015-01-11              shot           gun
# 3      63           Jose Ceja  2015-01-15              shot         knife
# 4      68       Zaki Shinwary  2015-01-16  shot and Tasered         knife
# ..    ...                 ...         ...               ...           ...
# 899  6568        Anthony Loia  2021-02-06              shot           gun
# 900  6566  Brooke Leann Blair  2021-02-07              shot    toy weapon
# 901  6614                 NaN  2021-02-15              shot  undetermined
# 902  6615     Royce Robertson  2021-02-15              shot           gun
# 903  6632                 NaN  2021-02-25              shot  undetermined
#
#       age gender race             city state  ...  is_geocoding_exact  \
# ...

# %%
cali_merged = cali_merged.drop_duplicates(['id'])
cali_merged
# Out:
#        id                name        date   manner_of_death         armed  \
# 0       8     Matthew Hoffman  2015-01-04              shot    toy weapon
# 1      19      Patrick Wetter  2015-01-06  shot and Tasered         knife
# 2      43      Brian  Barbosa  2015-01-11              shot           gun
# 3      63           Jose Ceja  2015-01-15              shot         knife
# 4      68       Zaki Shinwary  2015-01-16  shot and Tasered         knife
# ..    ...                 ...         ...               ...           ...
# 899  6568        Anthony Loia  2021-02-06              shot           gun
# 900  6566  Brooke Leann Blair  2021-02-07              shot    toy weapon
# 901  6614                 NaN  2021-02-15              shot  undetermined
# 902  6615     Royce Robertson  2021-02-15              shot           gun
# 903  6632                 NaN  2021-02-25              shot  undetermined
#
#       age gender race             city state  ...  is_geocoding_exact  \
# ...

# %%
cali_merged.to_csv('data/cali_combined.csv')
