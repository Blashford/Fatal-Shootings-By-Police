# %%
import pandas as pd

# %%
df = pd.read_csv('data/cali_combined.csv')
df
# Out:
#      Unnamed: 0    id                name        date   manner_of_death  \
# 0             0     8     Matthew Hoffman  2015-01-04              shot
# 1             1    19      Patrick Wetter  2015-01-06  shot and Tasered
# 2             2    43      Brian  Barbosa  2015-01-11              shot
# 3             3    63           Jose Ceja  2015-01-15              shot
# 4             4    68       Zaki Shinwary  2015-01-16  shot and Tasered
# ..          ...   ...                 ...         ...               ...
# 895         899  6568        Anthony Loia  2021-02-06              shot
# 896         900  6566  Brooke Leann Blair  2021-02-07              shot
# 897         901  6614                 NaN  2021-02-15              shot
# 898         902  6615     Royce Robertson  2021-02-15              shot
# 899         903  6632                 NaN  2021-02-25              shot
#
#             armed   age gender race             city  ... is_geocoding_exact  \
# ...

# %%
grouped = df.groupby('city')
grouped['age']
